# %%
import pandas as pd
from pathlib import Path
import seaborn as sns

# %%
df = pd.read_csv(
    Path("data") / "reviews_with_lemmas.csv",
    dtype={
        "appId": str,
        "language": str,
        "reviewId": str,
        "score": "int8",
        "content": str,
        "thumbsUpCount": "int32",
        "reviewCreatedVersion": str,
        "replyContent": str,
        "appVersion": str,
        "lemmas": str,
    },
    parse_dates=["at", "repliedAt"],
)
apps_ids = df["appId"].unique()
languages = df["language"].unique()

# %%
df["appId"].value_counts()
# Out:
# appId
# com.google.android.apps.maps           88354
# app.com.example.szymi.myapplication    22616
# cz.seznam.mapy                         14314
# pl.mapa_turystyczna.app                 8057
# com.windyty.android                     6496
# com.strava                              4299
# de.komoot.android                       3173
# pl.janpogocki.icm.pogoda                3153
# pl.traseo2                              2325
# menion.android.locus                    1511
# com.meteoblue.droid                      809
# no.nrk.yr                                693
# info.burzowo                             589
# com.pagasolutions.emergencycall_pl       526
# com.alltrails.alltrails                  511
# org.peakfinder.area.alps                  81
# com.verdant.kgp                           72
# com.verdant.wkt                            1
# Name: count, dtype: int64
